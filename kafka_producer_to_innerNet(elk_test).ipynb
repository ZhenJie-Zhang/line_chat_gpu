# %%
from kafka import KafkaProducer
import sys, random, datetime, time, json

while True:
    if __name__ == "__main__":
        # 設定要連線到Kafka集群的相關設定, 並產生一個Kafka的Producer的實例
        producer1 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )

        producer2 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )


        try:
            device_id = "001"
            t = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            temp = round(random.uniform(18, 30), 2)
            humidity = random.randint(0, 100)
            rd = random.random()
            tt = {"device_id": device_id, "timestamp": t, "Temperature": temp, 'rd': rd}
            hh = {"device_id": device_id, "timestamp": t, "bpm": humidity, 'rd': rd}

            print("Start sending messages ...")
            # 產生要發佈到Kafka的訊息
    #         producer1.send(topic="temperature", value=tt)
    #         producer2.send(topic="humidity", value=hh)
            # producer.send(topic=topicName, key=msgKey, value=msgValue)
            future1 = producer1.send(topic="temperature", value=tt)
            record_metadata1 = future1.get(timeout=10)
            print(record_metadata1)

            future2 = producer2.send(topic="bpm_test2", value=hh)
            record_metadata2 = future2.get(timeout=10)
            print(record_metadata2)
            print("Message sending completed!")

        except Exception as e:
            # 錯誤處理
            e_type, e_value, e_traceback = sys.exc_info()
            print("type ==> %s" % (e_type))
            print("value ==> %s" % (e_value))
            print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
            print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
            print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))


        finally:
            # 關掉Producer實例的連線
            producer1.close()
            producer2.close()
#             time.sleep(2)
# Out:
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=571, timestamp=1571728380619, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=210, timestamp=1571728380625, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=572, timestamp=1571728380847, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=211, timestamp=1571728380854, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=573, timestamp=1571728381078, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=212, timestamp=1571728381088, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=574, timestamp=1571728381322, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=213, timestamp=1571728381328, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=575, timestamp=1571728381556, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=214, timestamp=1571728381562, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=576, timestamp=1571728381786, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=215, timestamp=1571728381792, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=577, timestamp=1571728382019, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=216, timestamp=1571728382024, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=578, timestamp=1571728382248, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=217, timestamp=1571728382254, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=579, timestamp=1571728382476, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=218, timestamp=1571728382484, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=580, timestamp=1571728382710, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=219, timestamp=1571728382718, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=581, timestamp=1571728382942, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=220, timestamp=1571728382948, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=582, timestamp=1571728383169, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=221, timestamp=1571728383179, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=583, timestamp=1571728383426, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=222, timestamp=1571728383432, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=584, timestamp=1571728383654, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=223, timestamp=1571728383661, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=585, timestamp=1571728383885, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=224, timestamp=1571728383890, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=586, timestamp=1571728384112, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=225, timestamp=1571728384119, checksum=None, serialized_key_size=-1, serialized_value_size=91, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=587, timestamp=1571728384340, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=226, timestamp=1571728384347, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=588, timestamp=1571728384571, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=227, timestamp=1571728384577, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=589, timestamp=1571728384802, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=228, timestamp=1571728384812, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=590, timestamp=1571728385038, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=229, timestamp=1571728385044, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=591, timestamp=1571728385265, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=230, timestamp=1571728385273, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=592, timestamp=1571728385496, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=231, timestamp=1571728385503, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=593, timestamp=1571728385725, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=232, timestamp=1571728385731, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=594, timestamp=1571728385955, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=233, timestamp=1571728385961, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=595, timestamp=1571728386185, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=234, timestamp=1571728386192, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=596, timestamp=1571728386415, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=235, timestamp=1571728386421, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=597, timestamp=1571728386646, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=236, timestamp=1571728386653, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=598, timestamp=1571728386876, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=237, timestamp=1571728386884, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=599, timestamp=1571728387108, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=238, timestamp=1571728387114, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=600, timestamp=1571728387337, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=239, timestamp=1571728387344, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=601, timestamp=1571728387567, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=240, timestamp=1571728387573, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=602, timestamp=1571728387822, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=241, timestamp=1571728387830, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=603, timestamp=1571728388053, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset
checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=658, timestamp=1571728400839, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=297, timestamp=1571728400845, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=659, timestamp=1571728401100, checksum=None, serialized_key_size=-1, serialized_value_size=106, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=298, timestamp=1571728401107, checksum=None, serialized_key_size=-1, serialized_value_size=95, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# ...
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4497, timestamp=1571729379845, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4859, timestamp=1571729380068, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4498, timestamp=1571729380074, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4860, timestamp=1571729380299, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4499, timestamp=1571729380305, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4861, timestamp=1571729380528, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4500, timestamp=1571729380534, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4862, timestamp=1571729380758, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4501, timestamp=1571729380764, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4863, timestamp=1571729380993, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4502, timestamp=1571729381003, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4864, timestamp=1571729381225, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4503, timestamp=1571729381231, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4865, timestamp=1571729381454, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4504, timestamp=1571729381462, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4866, timestamp=1571729381685, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4505, timestamp=1571729381691, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4867, timestamp=1571729381916, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4506, timestamp=1571729381923, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4868, timestamp=1571729382148, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4507, timestamp=1571729382154, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4869, timestamp=1571729382378, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4508, timestamp=1571729382385, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4870, timestamp=1571729382609, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4509, timestamp=1571729382616, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4871, timestamp=1571729382840, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4510, timestamp=1571729382847, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4872, timestamp=1571729383072, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4511, timestamp=1571729383078, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4873, timestamp=1571729383302, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4512, timestamp=1571729383309, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4874, timestamp=1571729383532, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4513, timestamp=1571729383540, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4875, timestamp=1571729383763, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4514, timestamp=1571729383770, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4876, timestamp=1571729383994, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4515, timestamp=1571729384002, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4877, timestamp=1571729384252, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4516, timestamp=1571729384258, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4878, timestamp=1571729384483, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4517, timestamp=1571729384490, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4879, timestamp=1571729384714, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4518, timestamp=1571729384720, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4880, timestamp=1571729384942, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4519, timestamp=1571729384949, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4881, timestamp=1571729385173, checksum=None, serialized_key_size=-1, serialized_value_size=108, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4520, timestamp=1571729385180, checksum=None, serialized_key_size=-1, serialized_value_size=97, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4882, timestamp=1571729385405, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4521, timestamp=1571729385411, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=4883, timestamp=1571729385635, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='bpm_test2', partition=0, topic_partition=TopicPartition(topic='bpm_test2', partition=0), offset=4522, timestamp=1571729385644, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-406a11f5b3ad> in <module>
#      22             # 指定msgValue的序列化器
#      23             #value_serializer = str.encode,
# ---> 24             value_serializer = lambda m: json.dumps(m).encode('ascii'),
#      25         )
#      26
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     380                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 381                              **self.config)
#     382
#     383         # Get auto-discovered version from client if necessary
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in __init__(self, **configs)
#     238         if self.config['api_version'] is None:
#     239             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 240             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     241
#     242     def _can_bootstrap(self):
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     906             try:
#     907                 remaining = end - time.time()
# --> 908                 version = conn.check_version(timeout=remaining, strict=strict, topics=list(self.config['bootstrap_topics_filter']))
#     909                 if version >= (0, 10, 0):
#     910                     # cache the api versions map if it's available (starting
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/conn.py in check_version(self, timeout, strict, topics)
#    1173             f = self.send(request)
#    1174             # HACK: sleeping to wait for socket to send bytes
# -> 1175             time.sleep(0.1)
#    1176             # when broker receives an unrecognized request API
#    1177             # it abruptly closes our socket.
#
# KeyboardInterrupt:
